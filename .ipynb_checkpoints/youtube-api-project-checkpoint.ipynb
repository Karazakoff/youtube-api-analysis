# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from dateutil.parser import parse

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import ticker


# NLP
# !pip3 install wordcloud
# from wordcloud import WordCloud

# %%
api_key = 'AIzaSyCR1Wc4-GsgA4W_F3nCPDlRQDfzXw0Vxjg'

# %%
api_service_name = "youtube"
api_version = "v3"

channel_ids = ['UCoOae5nYA7VqaXzerajD0lg',
               # more channels here
]

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey = api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(
        part = "snippet,contentDetails,statistics",
        id = ",".join(channel_ids)
    )

    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalViews': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers      views totalViews                playlistId
# 0  Ali Abdaal     3650000  253717282        530  UUoOae5nYA7VqaXzerajD0lg

# %%
playlist_id = 'UUoOae5nYA7VqaXzerajD0lg'
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(part = "snippet,contentDetails", playlistId=playlist_id,
                                          maxResults = 50)
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(part = "contentDetails", 
            playlistId = playlist_id,
            maxResults = 50,
            pageToken = next_page_token
        )
    
        response = request.execute()
        
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        
        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
# Get video IDs
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 527

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        
        request = youtube.videos().list(
            part='snippet,contentDetails,statistics',
            id=','.join(video_ids[i:i + 50])
        )

        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)

    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#         video_id channelTitle  \
# 0    WizT_VdtOYM   Ali Abdaal
# 1    hdabng2B9vU   Ali Abdaal
# 2    38h0Zuw3cv4   Ali Abdaal
# 3    UASlgjC9fz0   Ali Abdaal
# 4    knPdMQ44jKc   Ali Abdaal
# ..           ...          ...
# 522  7APfFjfnNBc   Ali Abdaal
# 523  gBpBLTSCb4s   Ali Abdaal
# 524  Va0tSdPADpA   Ali Abdaal
# 525  XJHM0fEH3ss   Ali Abdaal
# 526  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0      How to Become Luckier - An Evidence-Based Guide
# 1                     The Power of Cold Emails #shorts
# 2    $100m CEO Alex Hormozi's advice for entreprene...
# 3                              The IKEA effect #shorts
# 4                                How I Failed in 2022…
# ..                                                 ...
# 522  Payphone (Maroon 5) - Katherine Macfarland & A...
# 523            6med UKCAT Crash Course - In a Nutshell
# 524             6med BMAT Crash Course - In a Nutshell
# 525  Rolling in the Deep (Adele) - Duranka Perera &...
# 526           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    This video is sponsored by Curiosity Stream. G...
# 1    If you liked this, you might like my podcast D...
# 2    If you liked this, you might like my podcast D...
# 3    If you liked this, you might like my podcast D...
# 4    Go to our sponsor https://betterhelp.com/aliab...
# ..                                                 ...
# 522  First cover of 2017! We both love this song, s...
# 523  The 6med UKCAT Crash Course is the most effect...
# 524  The 6med BMAT Crash Course is the most effecti...
# 525  Our first 'proper' video! One of our all-time ...
# 526  First attempt at playing around with this sort...
#
#                                                   tags           publishedAt  \
# 0    [Ali Abdaal, Ali abdal, ali abdaal podcast, de...  2022-12-22T14:00:15Z
# 1                              [Ali Abdaal, Ali abdal]  2022-12-21T16:21:48Z
# 2                              [Ali Abdaal, Ali abdal]  2022-12-19T13:00:01Z
# 3                              [Ali Abdaal, Ali abdal]  2022-12-17T13:00:23Z
# 4                              [Ali Abdaal, Ali abdal]  2022-12-16T12:00:33Z
# ..                                                 ...                   ...
# 522        [payphone, maroon 5, acoustic cover, cover]  2017-01-04T23:13:51Z
# 523            ed, medical school, ukcat, medicine]  2016-05-09T18:45:18Z
# 524           [BMAT, 6med, medicine, medical students]  2016-04-27T09:04:49Z
# 525      [rolling in the deep, adele, cover, acoustic]  2016-04-05T09:05:29Z
# 526                                               None  2016-03-27T19:30:11Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0       37886      2530           None          152  PT12M42S         hd
# 1       52875      4954           None           25     PT49S         hd
# 2       31887      2448           None           17      PT1M         hd
# 3      115002     12639           None           81     PT45S         hd
# 4      221668      9128           None         1629   PT40M2S         hd
# ..        ...       ...            ...          ...       ...        ...
# 522     77895      1998           None          114   PT2M35S         hd
# 523     13893       101           None            4   PT2M11S         hd
# 524     34865       260           None            8   PT2M18S         hd
# 525     49513       622           None           29   PT2M29S         hd
# 526    101415      1273           None          123   PT1M43S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 522   false
# 523   false
# 524   false
# 525   false
# 526   false
#
# [527 rows x 13 columns]

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    for video_id in video_ids:
        try:
            
            request = youtube.commentThreads().list(
                part = 'snippet,replies',
                videoId = video_id
            )
            response = request.execute()

            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items']]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
        except:
            continue
    
    return pd.DataFrame(all_comments)

# %%
comments_df = get_comments_in_videos(youtube, video_ids)

# %%
comments_df.head()
# Out:
#       video_id                                           comments
# 0  WizT_VdtOYM  [This video is sponsored by Curiosity Stream. ...
# 1  hdabng2B9vU  [If you liked this, you might like my podcast ...
# 2  38h0Zuw3cv4  [If you liked this, you might like my podcast ...
# 3  UASlgjC9fz0  [If you liked this, you might like my podcast ...
# 4  knPdMQ44jKc  [Go to our sponsor https://betterhelp.com/alia...

# %% [markdown]
# ## Data pre-processing

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, axis = 1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parse(x))
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    WizT_VdtOYM   Ali Abdaal
# 1    hdabng2B9vU   Ali Abdaal
# 2    38h0Zuw3cv4   Ali Abdaal
# 3    UASlgjC9fz0   Ali Abdaal
# 4    knPdMQ44jKc   Ali Abdaal
# ..           ...          ...
# 522  7APfFjfnNBc   Ali Abdaal
# 523  gBpBLTSCb4s   Ali Abdaal
# 524  Va0tSdPADpA   Ali Abdaal
# 525  XJHM0fEH3ss   Ali Abdaal
# 526  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0      How to Become Luckier - An Evidence-Based Guide
# 1                     The Power of Cold Emails #shorts
# 2    $100m CEO Alex Hormozi's advice for entreprene...
# 3                              The IKEA effect #shorts
# 4                                How I Failed in 2022…
# ..                                                 ...
# 522  Payphone (Maroon 5) - Katherine Macfarland & A...
# 523            6med UKCAT Crash Course - In a Nutshell
# 524             6med BMAT Crash Course - In a Nutshell
# 525  Rolling in the Deep (Adele) - Duranka Perera &...
# 526           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    This video is sponsored by Curiosity Stream. G...
# 1    If you liked this, you might like my podcast D...
# 2    If you liked this, you might like my podcast D...
# 3    If you liked this, you might like my podcast D...
# 4    Go to our sponsor https://betterhelp.com/aliab...
# ..                                                 ...
# 522  First cover of 2017! We both love this song, s...
# 523  The 6med UKCAT Crash Course is the most effect...
# 524  The 6med BMAT Crash Course is the most effecti...
# 525  Our first 'proper' video! One of our all-time ...
# 526  First attempt at playing around with this sort...
#
#                                                   tags  \
# 0    [Ali Abdaal, Ali abdal, ali abdaal podcast, de...
# 1                              [Ali Abdaal, Ali abdal]
# 2                              [Ali Abdaal, Ali abdal]
# 3                              [Ali Abdaal, Ali abdal]
# 4                              [Ali Abdaal, Ali abdal]
# ..                                                 ...
# 522        [payphone, maroon 5, acoustic cover, cover]
# 523            ed, medical school, ukcat, medicine]
# 524           [BMAT, 6med, medicine, medical students]
# 525      [rolling in the deep, adele, cover, acoustic]
# 526                                               None
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2022-12-22 14:00:15+00:00    37886.0     2530.0             NaN
# 1   2022-12-21 16:21:48+00:00    52875.0     4954.0             NaN
# 2   2022-12-19 13:00:01+00:00    31887.0     2448.0             NaN
# 3   2022-12-17 13:00:23+00:00   115002.0    12639.0             NaN
# 4   2022-12-16 12:00:33+00:00   221668.0     9128.0             NaN
# ..                        ...        ...        ...             ...
# 522 2017-01-04 23:13:51+00:00    77895.0     1998.0             NaN
# 523 2016-05-09 18:45:18+00:00    13893.0      101.0             NaN
# 524 2016-04-27 09:04:49+00:00    34865.0      260.0             NaN
# 525 2016-04-05 09:05:29+00:00    49513.0      622.0             NaN
# 526 2016-03-27 19:30:11+00:00   101415.0     1273.0             NaN
#
#      commentCount  duration definition caption publishDayName
# 0           152.0  PT12M42S         hd   false       Thursday
# 1            25.0     PT49S         hd   false      Wednesday
# 2            17.0      PT1M         hd   false         Monday
# 3            81.0     PT45S         hd   false       Saturday
# 4          1629.0   PT40M2S         hd   false         Friday
# ..            ...       ...        ...     ...            ...
# 522         114.0   PT2M35S         hd   false      Wednesday
# 523           4.0   PT2M11S         hd   false         Monday
# 524           8.0   PT2M18S         hd   false      Wednesday
# 525          29.0   PT2M29S         hd   false        Tuesday
# 526         123.0   PT1M43S         hd   false         Sunday
#
# [527 rows x 14 columns]

# %%
# convert duration to seconds
def iso_duration_to_time(duration: str) -> str:
    hours, minutes, seconds = 0, 0, 0
    if 'H' in duration:
        hours = int(duration.split('H')[0][2:])
    if 'M' in duration:
        minutes = int(duration.split('M')[0][-1:])
    if 'S' in duration:
        seconds = int(duration.split('S')[0][-1:])
    total_seconds = hours * 3600 + minutes * 60 + seconds
    return total_seconds

# %%
video_df['durationSecs'] = video_df['duration'].apply(lambda x: iso_duration_to_time(x))
video_df[['durationSecs', 'duration']]
# Out:
#      durationSecs  duration
# 0             122  PT12M42S
# 1               9     PT49S
# 2              60      PT1M
# 3               5     PT45S
# 4               2   PT40M2S
# ..            ...       ...
# 522           125   PT2M35S
# 523           121   PT2M11S
# 524           128   PT2M18S
# 525           129   PT2M29S
# 526            63   PT1M43S
#
# [527 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    WizT_VdtOYM   Ali Abdaal
# 1    hdabng2B9vU   Ali Abdaal
# 2    38h0Zuw3cv4   Ali Abdaal
# 3    UASlgjC9fz0   Ali Abdaal
# 4    knPdMQ44jKc   Ali Abdaal
# ..           ...          ...
# 522  7APfFjfnNBc   Ali Abdaal
# 523  gBpBLTSCb4s   Ali Abdaal
# 524  Va0tSdPADpA   Ali Abdaal
# 525  XJHM0fEH3ss   Ali Abdaal
# 526  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0      How to Become Luckier - An Evidence-Based Guide
# 1                     The Power of Cold Emails #shorts
# 2    $100m CEO Alex Hormozi's advice for entreprene...
# 3                              The IKEA effect #shorts
# 4                                How I Failed in 2022…
# ..                                                 ...
# 522  Payphone (Maroon 5) - Katherine Macfarland & A...
# 523            6med UKCAT Crash Course - In a Nutshell
# 524             6med BMAT Crash Course - In a Nutshell
# 525  Rolling in the Deep (Adele) - Duranka Perera &...
# 526           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    This video is sponsored by Curiosity Stream. G...
# 1    If you liked this, you might like my podcast D...
# 2    If you liked this, you might like my podcast D...
# 3    If you liked this, you might like my podcast D...
# 4    Go to our sponsor https://betterhelp.com/aliab...
# ..                                                 ...
# 522  First cover of 2017! We both love this song, s...
# 523  The 6med UKCAT Crash Course is the most effect...
# 524  The 6med BMAT Crash Course is the most effecti...
# 525  Our first 'proper' video! One of our all-time ...
# 526  First attempt at playing around with this sort...
#
#                                                   tags  \
# 0    [Ali Abdaal, Ali abdal, ali abdaal podcast, de...
# 1                              [Ali Abdaal, Ali abdal]
# 2                              [Ali Abdaal, Ali abdal]
# 3                              [Ali Abdaal, Ali abdal]
# 4                              [Ali Abdaal, Ali abdal]
# ..                                                 ...
# 522        [payphone, maroon 5, acoustic cover, cover]
# 523            ed, medical school, ukcat, medicine]
# 524           [BMAT, 6med, medicine, medical students]
# 525      [rolling in the deep, adele, cover, acoustic]
# 526                                               None
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2022-12-22 14:00:15+00:00    37886.0     2530.0             NaN
# 1   2022-12-21 16:21:48+00:00    52875.0     4954.0             NaN
# 2   2022-12-19 13:00:01+00:00    31887.0     2448.0             NaN
# 3   2022-12-17 13:00:23+00:00   115002.0    12639.0             NaN
# 4   2022-12-16 12:00:33+00:00   221668.0     9128.0             NaN
# ..                        ...        ...        ...             ...
# 522 2017-01-04 23:13:51+00:00    77895.0     1998.0             NaN
# 523 2016-05-09 18:45:18+00:00    13893.0      101.0             NaN
# 524 2016-04-27 09:04:49+00:00    34865.0      260.0             NaN
# 525 2016-04-05 09:05:29+00:00    49513.0      622.0             NaN
# 526 2016-03-27 19:30:11+00:00   101415.0     1273.0             NaN
#
#      commentCount  duration definition caption publishDayName  durationSecs  \
# 0           152.0  PT12M42S         hd   false       Thursday           122
# 1            25.0     PT49S         hd   false      Wednesday             9
# 2            17.0      PT1M         hd   false         Monday            60
# 3            81.0     PT45S         hd   false       Saturday             5
# 4          1629.0   PT40M2S         hd   false         Friday             2
# ..            ...       ...        ...     ...            ...           ...
# 522         114.0   PT2M35S         hd   false      Wednesday           125
# 523           4.0   PT2M11S         hd   false         Monday           121
# 524           8.0   PT2M18S         hd   false      Wednesday           128
# 525          29.0   PT2M29S         hd   false        Tuesday           129
# 526         123.0   PT1M43S         hd   false         Sunday            63
#
#      tagCount
# 0          23
# 1           2
# 2           2
# 3           2
# 4           2
# ..        ...
# 522         4
# 523         4
# 524         4
# 525         4
# 526         0
#
# [527 rows x 16 columns]

# %% [markdown]
# ## Best performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending = False)[:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x / 1000) + 'K'))

# %% [markdown]
# ## Worst performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending = True)[:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x / 1000) + 'K'))

# %% [markdown]
# ## View distribution per video

# %%
sns.violinplot(video_df['channelTitle'], video_df['viewCount'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ## Views vs. Likes and Comments

# %%
fig, ax = plt.subplots(1, 2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ## Video duration

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins = 50)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ## Wordcloud for video titles

# %%
# Not worling, need to fix when I have free time

# import nltk
# nltk.download('stopwords')

# stop_words = set(stopwords.words('english'))
# video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

# all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
# all_words_str = " ".join(all_words)

# def plot_cloud(wordcloud):
#     plt.figure(figsize = (30, 20))
#     plt.imshow(wordcloud)
#     plt.axis('off');

# wordcloud = WordCloud(width = 2000, height = 1000, random_state = 1, background_color = 'black',
#                      colormap = 'viridis', collocations = False).generate(all_words_str)

# plot_cloud(wordcloud)

# %% [markdown]
# ## Upload schedule

# %%
day_df = pd.DataFrame(video_df['publishDayName'].value_counts())
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x = 'index', y = 'publishDayName', rot = 0)
